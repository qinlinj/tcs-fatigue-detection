# %%
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')

img = 'frontal_fatigue_pose_sideway/frame_1.jpg'
model.predict(img, save = True, conf=0.5)
# Out:
# ...
# 100%|██████████████████████████████████████| 6.51M/6.51M [00:00<00:00, 37.1MB/s]
#
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /Users/tejovinay/Documents/CMU/Sem_3/Capstone/frontal_fatigue_pose_sideway/frame_1.jpg: 384x640 2 persons, 282.4ms
# Speed: 6.1ms preprocess, 282.4ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/pose/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  orig_img: array([[[ 68,  95, 109],
#          [ 67,  94, 108],
#          [ 67,  94, 108],
#          ...,
#          [ 66,  96, 113],
#          [ 61,  91, 108],
#          [ 58,  88, 105]],
#
#         [[ 67,  94, 108],
#          [ 67,  94, 108],
#          [ 66,  93, 107],
#          ...,
#          [ 63,  93, 110],
#          [ 57,  87, 104],
# ...

# %%
video = 'videos/frontal_fatigue_pose_sideway.MOV'
model.predict(video, save = True, conf=0.5)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/872) /Users/tejovinay/Documents/CMU/Sem_3/Capstone/videos/frontal_fatigue_pose_sideway.MOV: 384x640 2 persons, 192.6ms
# video 1/1 (2/872) /Users/tejovinay/Documents/CMU/Sem_3/Capstone/videos/frontal_fatigue_pose_sideway.MOV: 384x640 2 persons, 123.1ms
# video 1/1 (3/872) /Users/tejovinay/Documents/CMU/Sem_3/Capstone/videos/frontal_fatigue_pose_sideway.MOV: 384x640 2 persons, 129.5ms
# ...
